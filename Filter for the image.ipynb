# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('len.png', 0)
plt.axis("off")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
Filter = [[-1, 0],
           [0, 1]]
img.shape
# Out:
# (220, 220)

# %%
img = img.reshape((-1, 220))
i, j = img.shape
ii, jj = np.array(Filter).shape

# %%
h = i - ii + 1
w = j - jj + 1

# %%
output = np.zeros((h, w))

# %%
for i in range(h):
    for j in range(w):
        for k in range(ii):
            for l in range(jj):
                output[i][j] += img[i + k][j + l] * Filter[k][l]

# %%
plt.imshow(output, cmap = "gray")
